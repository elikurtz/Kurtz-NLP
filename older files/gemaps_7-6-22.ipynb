# %%
import opensmile
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
dir_healthy = input("enter folder path for healthy clipped commands--> ")
dir_healthy_cha = input("enter the (full) path to your directory of healthy CHA files --> ")

dir_ad = input("enter folder path for AD clipped commands--> ")
dir_AD_cha = input("enter the (full) path to your directory of AD CHA files --> ")

dir_mci = input("enter folder path for MCI clipped commands--> ")
dir_MCI_cha = input("enter the (full) path to your directory of MCI CHA files --> ")

# %%
def extract(directory):
    files_from_dir = os.listdir(directory)
    feature_list = []
    os.chdir(directory)
    for i in files_from_dir:
        y = smile.process_file(i)
        y = pd.DataFrame(y)
        print(y)
        feature_list.append(y)
    merged_features_df = pd.concat(feature_list)
    return merged_features_df

# %%
healthy_features = extract(dir_healthy)    
ad_features = extract(dir_ad)
mci_features = extract(dir_mci)
print(healthy_features)
# Out:
#                                                                     audspec_lengthL1norm_sma_range  \
# file                                 start  end
# Healthy_participant015_command#1.wav 0 days 0 days 00:00:03.430000                        2.057848
#
#                                                                     audspec_lengthL1norm_sma_maxPos  \
# file                                 start  end
# Healthy_participant015_command#1.wav 0 days 0 days 00:00:03.430000                         0.267857
#
#                                                                     audspec_lengthL1norm_sma_minPos  \
# file                                 start  end
# Healthy_participant015_command#1.wav 0 days 0 days 00:00:03.430000                         0.047619
#
#                                                                     audspec_lengthL1norm_sma_quartile1  \
# file                                 start  end
# ...
