# %%
import os
import opensmile
import pandas as pd
import numpy as np
from natsort import natsorted
import pandas as pd
from pydub import AudioSegment as AS
from ChaFile import *
from difflib import SequenceMatcher as sm


smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

dir_healthy_wav = input("enter the (full) path to your directory of healthy WAV files --> ")
dir_healthy_cha = input("enter the (full) path to your directory of healthy CHA files --> ")

dir_AD_wav = input("enter the (full) path to your directory of AD WAV files --> ")
dir_AD_cha = input("enter the (full) path to your directory of AD CHA files --> ")

dir_MCI_wav = input("enter the (full) path to your directory of MCI WAV files --> ")
dir_MCI_cha = input("enter the (full) path to your directory of MCI CHA files --> ")

# %%
def checker(wav, cha):
    files_from_dir = os.listdir(wav)
    files_from_dir_2 = os.listdir(cha)
    if len(files_from_dir) != len(files_from_dir_2):
        quit("not equal")

checker(dir_healthy_wav, dir_healthy_cha)
checker(dir_AD_wav, dir_AD_cha)
checker(dir_MCI_wav, dir_MCI_cha)

AD_cha_files = natsorted(os.listdir(dir_AD_cha))
AD_wav_files = natsorted(os.listdir(dir_AD_wav))

MCI_cha_files = natsorted(os.listdir(dir_MCI_cha))
MCI_wav_files = natsorted(os.listdir(dir_MCI_wav))

Healthy_cha_files = natsorted(os.listdir(dir_healthy_cha))
Healthy_wav_files = natsorted(os.listdir(dir_healthy_wav))

# %%
keys_1 = ["command_1", "command_2", "command_3", "command_4", "command_5", "command_6", "command_7", "command_8", "command_9", 
"command_10", "command_11", "command_12", "command_13", "command_14", "command_15", "command_16", "command_17", "command_18", "command_19",
"command_20", "command_21", "command_22", "command_23", "command_24", "command_25", "command_26", "command_27", "command_28", "command_29",
"command_30", "command_31", "command_32", "command_33"]

# keywords = ["weather", "date", "time", "Thanksgiving", ["chocolate", "chip", "cookies"], ["two", "four"], "tablespoons", "symptom", "classical",
# ["volume", "eight"], "jazz", ["volume", "six"], "stop", "laundry", "dog", "reminders", "birthday", 
# ["five", "seconds"], "alarm", ["oranges", "grapes"], ["what", "is", "in", "shopping"], "call", ["hang", "up"], "find", "quit", ["bedroom", "light", "on"],
# "red", "brightness", ["bedroom", "light", "off"], ["open", "kitchen", "camera"], "hide", ["white", "collar"], "pause", "yes"]

COMMANDS = ["Alexa what is the weather outside ? ",
"Alexa what is today's date ? ", 
"Alexa what time is it ? ", 
"Alexa when is Thanksgiving ? ",
"Alexa how do you bake chocolate chip cookies ? ",
"Alexa what is two times four ? ",
"Alexa how many tablespoons in a cup ? ",
"Alexa how do you spell symptom ? ",
"Alexa play classical music . ",
"Alexa volume eight . ", 
"Alexa play jazz . ",
"Alexa volume six . ",
"Alexa stop . ",
"Alexa remind me to start the laundry tomorrow at two p_m . ",
"Alexa remind me to feed the dog at seven p_m everyday . ",
"Alexa tell me my reminders . ",
"Alexa remember my daughter's birthday is June first . ", 
"Alexa set a timer in five seconds . ",
"Alexa set my alarm for seven a_m tomorrow . ",
"Alexa add oranges and grapes to my shopping list . ",
"Alexa what is in my shopping list ? ",
"Alexa call six zero three six six zero two two zero three . ",
"Alexa hang up . ",
"Alexa find my phone . ",
"Alexa quit . ",
"Alexa turn the bedroom light on . ",
"Alexa turn the bedroom light red . ",
"Alexa change brightness to ten . ",
"Alexa turn off the bedroom light . ",
"Alexa open the kitchen camera . ",
"Alexa hide the kitchen camera . ",
"Alexa play white collar on fire tv . ",
"Alexa pause . "]

# %%
def unique():
    #Identifies unique words in commands
    keywords = []
    for i in range(len(COMMANDS)):
        word_cloud = COMMANDS[:]
        word_cloud.remove(COMMANDS[i])
        cloud = []
        for com in word_cloud:
            com = com.split(" ")
            for word in com:
                cloud.append(word)
        current = COMMANDS[i].split(" ")
        sublist = []
        for uni in current:
            if uni in cloud:
            #count += 1
                pass
            else:
                sublist.append(uni)
        keywords.append(sublist)
    print(keywords)
    print(len(COMMANDS))
    print(len(keywords))
    return keywords

keywords = unique()
# Out:
# [['weather', 'outside'], ["today's", 'date'], ['time', 'it'], ['when', 'Thanksgiving'], ['bake', 'chocolate', 'chip', 'cookies'], ['times', 'four'], ['many', 'tablespoons', 'cup'], ['spell', 'symptom'], ['classical', 'music'], ['eight'], ['jazz'], [], ['stop'], ['start', 'laundry'], ['feed', 'dog', 'everyday'], ['tell', 'reminders'], ['remember', "daughter's", 'birthday', 'June', 'first'], ['timer', 'five', 'seconds'], ['alarm', 'for', 'a_m'], ['add', 'oranges', 'and', 'grapes'], [], ['call', 'zero', 'three', 'zero', 'zero', 'three'], ['hang', 'up'], ['find', 'phone'], ['quit'], [], ['red'], ['change', 'brightness', 'ten'], ['off'], ['open'], ['hide'], ['white', 'collar', 'fire', 'tv'], ['pause']]
# 33
# 33

# %%
keywords[11] = ["Alexa", "volume", "six"]
keywords[21] = ["call"]
keywords[20] = ["Alexa", "what", "is", "in", "my", "shopping", "list"]
keywords[25] = ["Alexa", "turn", "the", "bedroom", "light", "on"]
#These are the non-unique commands containing no unique words
#Maybe try 2-keywords? Or how to deal with (Volume six / Volume eight) <---
dz = dict(zip(keys_1, keywords))

# %%
def distance(str1, str2):
    sql = sm(None, str1, str2)
    return sql.ratio()


def split_audio(timestamp, wav_dir, wav_file, cha_dir, participant, command_keys, custom_folder):
    temp = ("C:\\Users\\EliKurtz\\VSCode_files\\NLP\\Kurtz-NLP\\Audio gEMAPS\\temp")
    # full = ("C:\\Users\\EliKurtz\\VSCode_files\\NLP\\Kurtz-NLP\\Audio gEMAPS")
    full = custom_folder
    print(timestamp)
    os.chdir(wav_dir)
    part = AS.from_file(wav_file)
    t = any(isinstance(i, list) for i in timestamp)
    if not t:
        if len(timestamp) >= 1:
            clip = part[timestamp[0]:timestamp[1]]
            name = (participant + "_" + str(command_keys) + ".wav")
            os.chdir(full)
            clip.export(name, format="wav")
    else:
        count = 0
        for time in timestamp:
            print(timestamp)
            clip = part[time[0]:time[1]] 
            name = (participant + "_" + str(command_keys) + str(count) + ".wav")
            os.chdir(temp)
            clip.export(name, format="wav")
            count += 1
            print(os.listdir(temp))
        tempfiles = os.listdir(temp)
        combined_wav = AS.empty()
        for file in tempfiles:
            sound = AS.from_file(file, format="wav")
            combined_wav += sound
            os.remove(file)
        os.chdir(full)
        combined_wav.export(name, format="wav")
    os.chdir(cha_dir)


def categorize(cha_dir, wav_dir, cha_file, wav_file):
    os.chdir(cha_dir)
    cha = ChaFile(cha_file)
    lines = cha.getLines()
    data_set = []
    participant = cha_file
    unmatched_count = 1
    ur_commands_times = []
    um_command_times = []
    os.mkdir("C:\\Users\\EliKurtz\\VSCode_files\\NLP\\Kurtz-NLP\\Audio gEMAPS\\" + str(participant))
    custom_folder = "C:\\Users\\EliKurtz\\VSCode_files\\NLP\\Kurtz-NLP\\Audio gEMAPS\\" + str(participant)
    print(custom_folder)
    for data in lines:
        action_taken = 0
        utterance = data["xol"]
        timestamp = data["bullet"]
        utterance = utterance.split(" ")
        #print(utterance)
        dist = []
        for com in COMMANDS:
            dist.append(distance(com, data["xol"]))
        closest_neighbor = COMMANDS[dist.index(max(dist))]
        percent_match = (max(dist))
        #Identifies closest neighbor
        if utterance[0][0] == "[":
                #print("FLAG")
                keys = "UNRECOGNIZED COMMAND"
                closest_neighbor = "N/A"
                percent_match = "N/A"
                data_set.append([participant, keys, 0, utterance, timestamp, percent_match, closest_neighbor])
                ur_commands_times.append(timestamp)
        else:        
            for word in dz.values():
                if type(word) is list:
                    key_list = []
                    c = all(x in utterance for x in word)
                    if c:
                        action_taken += 1
                        keys = [k for k, v in dz.items() if v == word]
                        key_list.append(keys)
                        # print("matched", word, keys, timestamp)
                        data_set.append([participant, key_list, word, utterance, timestamp, percent_match, closest_neighbor])
                        split_audio(timestamp, wav_dir, wav_file, cha_dir, participant, key_list, custom_folder)
                        print("calling from 1")
                if word in utterance:
                    action_taken = 1
                    keys = [k for k, v in dz.items() if v == word]
                    #print("matched", word, keys, timestamp)
                    data_set.append([participant, keys, word, utterance, timestamp, percent_match, closest_neighbor])
                    split_audio(timestamp, wav_dir, wav_file, cha_dir, participant, key_list, custom_folder)
                    print("calling from 2")
            if action_taken == 0:
                keys = ["UNMATCHED COMMAND #" + str(unmatched_count)] 
                #print("FAILED TO MATCH")
                data_set.append([participant, keys, 0, utterance, timestamp, percent_match, closest_neighbor])
                unmatched_count += 1
                um_command_times.append(timestamp)
    if len(um_command_times) > 1:
        print(len(um_command_times))
        print(um_command_times)
        split_audio(um_command_times, wav_dir, wav_file, cha_dir, participant, "UNMATCHED", custom_folder)
        print("calling from 3")
    if len(um_command_times) > 1:
        split_audio(ur_commands_times, wav_dir, wav_file, cha_dir, participant, "UNRECOGNIZED", custom_folder)
    frame = pd.DataFrame(data_set)
    print("calling from 4")
    frame.columns = ["Participant", "Matched Command", "Unique Key-Words", 
    "Utterance", "Timestamp", "% Command-Utterance Match", "Closest Neighbor"]
    print(frame)
    os.chdir("..")
    # with pd.ExcelWriter("output.xlsx", mode="a", engine="openpyxl") as writer:
    #     frame.to_excel(writer, sheet_name=participant)

# %%
for i in range(len(AD_cha_files)):
    categorize(dir_AD_cha, dir_AD_wav, AD_cha_files[i], AD_wav_files[i])

for i in range(len(MCI_cha_files)):
    categorize(dir_MCI_cha, dir_MCI_wav, MCI_cha_files[i], MCI_wav_files[i])

for i in range(len(Healthy_cha_files)):
    categorize(dir_healthy_cha, dir_healthy_wav, Healthy_cha_files[i], Healthy_wav_files[i])
# Out:
# C:\Users\EliKurtz\VSCode_files\NLP\Kurtz-NLP\Audio gEMAPS\012.cha
# [0, 3250]
# calling from 1
# [3250, 5750]
# calling from 1
# [5750, 8490]
# calling from 1
# [8490, 11680]
# calling from 1
# [11680, 15530]
# calling from 1
# [15530, 18210]
# calling from 1
# [18210, 21580]
# calling from 1
# [21580, 24590]
# calling from 1
# [24590, 27780]
# calling from 1
# [27780, 30370]
# calling from 1
# [30370, 33390]
# calling from 1
# [33390, 37100]
# calling from 1
# [37100, 39720]
# calling from 1
# [39720, 41800]
# calling from 1
# [41800, 47600]
# calling from 1
# [47600, 53190]
# calling from 1
# [53190, 56380]
# calling from 1
# [56380, 60260]
# calling from 1
# [73580, 75480]
# calling from 1
# [75480, 79900]
# calling from 1
# [79900, 84980]
# calling from 1
# [87870, 91360]
# calling from 1
# [91360, 96530]
# calling from 1
# [96530, 102360]
# calling from 1
# [105580, 108410]
# calling from 1
# [108410, 111870]
# calling from 1
# [111870, 114760]
# calling from 1
# [114760, 117650]
# calling from 1
# [117650, 120720]
# calling from 1
# [120720, 124600]
# calling from 1
# [124600, 130080]
# calling from 1
# 6
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# ['012.cha_UNMATCHED0.wav']
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# ['012.cha_UNMATCHED0.wav', '012.cha_UNMATCHED1.wav']
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# ['012.cha_UNMATCHED0.wav', '012.cha_UNMATCHED1.wav', '012.cha_UNMATCHED2.wav']
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# ['012.cha_UNMATCHED0.wav', '012.cha_UNMATCHED1.wav', '012.cha_UNMATCHED2.wav', '012.cha_UNMATCHED3.wav']
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# ['012.cha_UNMATCHED0.wav', '012.cha_UNMATCHED1.wav', '012.cha_UNMATCHED2.wav', '012.cha_UNMATCHED3.wav', '012.cha_UNMATCHED4.wav']
# [[60260, 61470], [61470, 64720], [64720, 68930], [70140, 73580], [84980, 87870], [102360, 105580]]
# ['012.cha_UNMATCHED0.wav', '012.cha_UNMATCHED1.wav', '012.cha_UNMATCHED2.wav', '012.cha_UNMATCHED3.wav', '012.cha_UNMATCHED4.wav', '012.cha_UNMATCHED5.wav']
# calling from 3
# [[68930, 70140]]
# [[68930, 70140]]
# ['012.cha_UNRECOGNIZED0.wav']
# calling from 4
#    Participant         Matched Command  \
# 0      012.cha           [[command_1]]
# 1      012.cha           [[command_2]]
# 2      012.cha           [[command_3]]
# 3      012.cha           [[command_4]]
# 4      012.cha           [[command_5]]
# 5      012.cha           [[command_6]]
# 6      012.cha           [[command_7]]
# 7      012.cha           [[command_8]]
# 8      012.cha           [[command_9]]
# 9      012.cha          [[command_10]]
# 10     012.cha          [[command_13]]
# 11     012.cha          [[command_11]]
# 12     012.cha          [[command_12]]
# 13     012.cha          [[command_13]]
# 14     012.cha          [[command_14]]
# 15     012.cha          [[command_15]]
# 16     012.cha          [[command_16]]
# 17     012.cha          [[command_17]]
# 18     012.cha  [UNMATCHED COMMAND #1]
# 19     012.cha  [UNMATCHED COMMAND #2]
# 20     012.cha  [UNMATCHED COMMAND #3]
# 21     012.cha    UNRECOGNIZED COMMAND
# 22     012.cha  [UNMATCHED COMMAND #4]
# 23     012.cha          [[command_13]]
# 24     012.cha          [[command_19]]
# 25     012.cha          [[command_20]]
# 26     012.cha  [UNMATCHED COMMAND #5]
# 27     012.cha          [[command_21]]
# 28     012.cha          [[command_22]]
# 29     012.cha          [[command_22]]
# 30     012.cha  [UNMATCHED COMMAND #6]
# 31     012.cha          [[command_26]]
# 32     012.cha          [[command_27]]
# 33     012.cha          [[command_28]]
# 34     012.cha          [[command_29]]
# 35     012.cha          [[command_30]]
# 36     012.cha          [[command_31]]
# 37     012.cha          [[command_32]]
#
#                                  Unique Key-Words  \
# 0                              [weather, outside]
# 1                                 [today's, date]
# 2                                      [time, it]
# 3                            [when, Thanksgiving]
# 4                [bake, chocolate, chip, cookies]
# 5                                   [times, four]
# 6                        [many, tablespoons, cup]
# 7                                [spell, symptom]
# 8                              [classical, music]
# 9                                         [eight]
# 10                                         [stop]
# 11                                         [jazz]
# 12                           [Alexa, volume, six]
# 13                                         [stop]
# 14                               [start, laundry]
# 15                          [feed, dog, everyday]
# 16                              [tell, reminders]
# 17  [remember, daughter's, birthday, June, first]
# 18                                              0
# 19                                              0
# 20                                              0
# 21                                              0
# 22                                              0
# 23                                         [stop]
# 24                              [alarm, for, a_m]
# 25                    [add, oranges, and, grapes]
# 26                                              0
# 27      [Alexa, what, is, in, my, shopping, list]
# 28                                         [call]
# 29                                         [call]
# 30                                              0
# 31         [Alexa, turn, the, bedroom, light, on]
# 32                                          [red]
# 33                      [change, brightness, ten]
# 34                                          [off]
# 35                                         [open]
# 36                                         [hide]
# 37                      [white, collar, fire, tv]
#
#                                             Utterance         Timestamp  \
# 0       [Alexa, what, is, the, weather, outside, ?, ]         [0, 3250]
# 1               [Alexa, what, is, today's, date, ?, ]      [3250, 5750]
# 2                    [Alexa, what, time, is, it, ?, ]      [5750, 8490]
# 3                [Alexa, when, is, Thanksgiving, ?, ]     [8490, 11680]
# 4   [Alexa, how, do, you, bake, chocolate, chip, c...    [11680, 15530]
# 5            [Alexa, what, is, two, times, four, ?, ]    [15530, 18210]
# 6    [Alexa, how, many, tablespoons, in, a, cup, ?, ]    [18210, 21580]
# 7          [Alexa, how, do, you, spell, symptom, ?, ]    [21580, 24590]
# 8                [Alexa, play, classical, music, ., ]    [24590, 27780]
# 9                     [Alexa, volume, to, eight, ., ]    [27780, 30370]
# 10                                 [Alexa, stop, ., ]    [30370, 33390]
# 11                           [Alexa, play, jazz, ., ]    [33390, 37100]
# 12                          [Alexa, volume, six, ., ]    [37100, 39720]
# 13                                 [Alexa, stop, ., ]    [39720, 41800]
# 14  [Alexa, remind, me, to, start, the, laundry, t...    [41800, 47600]
# 15  [Alexa, remind, me, to, feed, the, dog, at, se...    [47600, 53190]
# 16              [Alexa, tell, me, my, reminders, ., ]    [53190, 56380]
# 17  [Alexa, remember, my, daughter's, birthday, is...    [56380, 60260]
# 18                                         [yes, ., ]    [60260, 61470]
# 19              [Alexa, set, a, timer, in, five, ., ]    [61470, 64720]
# 20                           [I, get, it, Alexa, ., ]    [64720, 68930]
# 21        [[*audio, could, not, be, understood], ., ]    [68930, 70140]
# 22                        [Alexa, five, seconds, ., ]    [70140, 73580]
# 23                                 [Alexa, stop, ., ]    [73580, 75480]
# 24  [Alexa, set, my, alarm, for, seven, a_m, tomor...    [75480, 79900]
# 25  [Alexa, add, oranges, and, grapes, to, my, sho...    [79900, 84980]
# 26                     [Alexa, what, is, my, gi, ?, ]    [84980, 87870]
# 27     [Alexa, what, is, in, my, shopping, list, ?, ]    [87870, 91360]
# 28               [Alexa, call, six, zero, three, ., ]    [91360, 96530]
# 29  [Alexa, call, six, zero, three, six, six, zero...   [96530, 102360]
# 30                     [Alexa, find, my, iphone, ., ]  [102360, 105580]
# 31        [Alexa, turn, on, the, bedroom, light, ., ]  [105580, 108410]
# 32       [Alexa, turn, the, bedroom, light, red, ., ]  [108410, 111870]
# 33          [Alexa, change, brightness, to, ten, ., ]  [111870, 114760]
# 34       [Alexa, turn, off, the, bedroom, light, ., ]  [114760, 117650]
# 35           [Alexa, open, the, kitchen, camera, ., ]  [117650, 120720]
# 36           [Alexa, hide, the, kitchen, camera, ., ]  [120720, 124600]
# 37    [Alexa, play, white, collar, on, fire, tv, ., ]  [124600, 130080]
#
#    % Command-Utterance Match  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# 5                        1.0
# 6                        1.0
# 7                        1.0
# 8                        1.0
# 9                   0.933333
# 10                       1.0
# 11                       1.0
# 12                       1.0
# 13                       1.0
# 14                       1.0
# 15                       1.0
# 16                       1.0
# 17                       1.0
# 18                  0.526316
# 19                     0.875
# 20                  0.533333
# 21                       N/A
# 22                  0.736842
# 23                       1.0
# 24                       1.0
# 25                       1.0
# 26                  0.782609
# 27                       1.0
# 28                  0.636364
# 29                  0.857143
# 30                  0.977778
# 31                  0.956522
# 32                       1.0
# 33                       1.0
# 34                       1.0
# 35                       1.0
# 36                       1.0
# 37                       1.0
#
#                                      Closest Neighbor
# 0                Alexa what is the weather outside ?
# 1                       Alexa what is today's date ?
# 2                            Alexa what time is it ?
# 3                       Alexa when is Thanksgiving ?
# 4     Alexa how do you bake chocolate chip cookies ?
# 5                     Alexa what is two times four ?
# 6              Alexa how many tablespoons in a cup ?
# 7                   Alexa how do you spell symptom ?
# 8                       Alexa play classical music .
# 9                               Alexa volume eight .
# 10                                      Alexa stop .
# 11                                 Alexa play jazz .
# 12                                Alexa volume six .
# 13                                      Alexa stop .
# 14  Alexa remind me to start the laundry tomorrow ...
# 15  Alexa remind me to feed the dog at seven p_m e...
# 16                      Alexa tell me my reminders .
# 17  Alexa remember my daughter's birthday is June ...
# 18                                      Alexa stop .
# 19               Alexa set a timer in five seconds .
# 20                                      Alexa stop .
# 21                                                N/A
# 22               Alexa set a timer in five seconds .
# 23                                      Alexa stop .
# 24       Alexa set my alarm for seven a_m tomorrow .
# 25  Alexa add oranges and grapes to my shopping li...
# 26                           Alexa what time is it ?
# 27               Alexa what is in my shopping list ?
# 28  Alexa call six zero three six six zero two two...
# 29  Alexa call six zero three six six zero two two...
# 30                             Alexa find my phone .
# 31                Alexa turn off the bedroom light .
# 32                Alexa turn the bedroom light red .
# 33                  Alexa change brightness to ten .
# 34                Alexa turn off the bedroom light .
# 35                   Alexa open the kitchen camera .
# 36                   Alexa hide the kitchen camera .
# 37              Alexa play white collar on fire tv .
# C:\Users\EliKurtz\VSCode_files\NLP\Kurtz-NLP\Audio gEMAPS\014.cha
# [0, 2800]
# calling from 1
# [2800, 5390]
# calling from 1
# [5390, 7620]
# calling from 1
# [7620, 11270]
# calling from 1
# [11270, 15840]
# calling from 1
# [15840, 19580]
# calling from 1
# [19580, 22920]
# calling from 1
# [22920, 26170]
# calling from 1
# [26170, 29930]
# calling from 1
# [29930, 33790]
# calling from 1
# [43110, 48650]
# calling from 1
# [48650, 54150]
# calling from 1
# [54150, 57640]
# calling from 1
# [57640, 63470]
# calling from 1
# [63470, 68170]
# calling from 1
# [68170, 72420]
# calling from 1
# [72420, 74020]
# calling from 1
# [74020, 79010]
# calling from 1
# [79010, 82630]
# calling from 1
# [85970, 88980]
# calling from 1
# [88980, 91790]
# calling from 1
# [91790, 102120]
# calling from 1
# [102120, 105110]
# calling from 1
# [105110, 108040]
# calling from 1
# [108040, 110910]
# calling from 1
# [110910, 115060]
# calling from 1
# [115060, 119060]
# calling from 1
# [119060, 123540]
# calling from 1
# [123540, 127060]
# calling from 1
# [127060, 130790]
# calling from 1
# [130790, 134550]
# calling from 1
# [134550, 140780]
# calling from 1
# [140780, 143220]
# calling from 1
# 2
# [[33790, 43110], [82630, 85970]]
# [[33790, 43110], [82630, 85970]]
# [[33790, 43110], [82630, 85970]]
# ['014.cha_UNMATCHED0.wav']
# [[33790, 43110], [82630, 85970]]
# ['014.cha_UNMATCHED0.wav', '014.cha_UNMATCHED1.wav']
# calling from 3
# []
# calling from 4
#    Participant         Matched Command  \
# 0      014.cha           [[command_1]]
# 1      014.cha           [[command_2]]
# 2      014.cha           [[command_3]]
# 3      014.cha           [[command_4]]
# 4      014.cha           [[command_5]]
# 5      014.cha           [[command_6]]
# 6      014.cha           [[command_7]]
# 7      014.cha           [[command_8]]
# 8      014.cha           [[command_9]]
# 9      014.cha          [[command_10]]
# 10     014.cha  [UNMATCHED COMMAND #1]
# 11     014.cha          [[command_14]]
# 12     014.cha          [[command_15]]
# 13     014.cha          [[command_16]]
# 14     014.cha          [[command_17]]
# 15     014.cha          [[command_18]]
# 16     014.cha          [[command_19]]
# 17     014.cha          [[command_13]]
# 18     014.cha          [[command_20]]
# 19     014.cha          [[command_22]]
# 20     014.cha  [UNMATCHED COMMAND #2]
# 21     014.cha          [[command_21]]
# 22     014.cha          [[command_23]]
# 23     014.cha          [[command_22]]
# 24     014.cha          [[command_23]]
# 25     014.cha          [[command_24]]
# 26     014.cha          [[command_25]]
# 27     014.cha          [[command_26]]
# 28     014.cha          [[command_27]]
# 29     014.cha          [[command_28]]
# 30     014.cha          [[command_29]]
# 31     014.cha          [[command_30]]
# 32     014.cha          [[command_31]]
# 33     014.cha          [[command_32]]
# 34     014.cha          [[command_33]]
#
#                                  Unique Key-Words  \
# 0                              [weather, outside]
# 1                                 [today's, date]
# 2                                      [time, it]
# 3                            [when, Thanksgiving]
# 4                [bake, chocolate, chip, cookies]
# 5                                   [times, four]
# 6                        [many, tablespoons, cup]
# 7                                [spell, symptom]
# 8                              [classical, music]
# 9                                         [eight]
# 10                                              0
# 11                               [start, laundry]
# 12                          [feed, dog, everyday]
# 13                              [tell, reminders]
# 14  [remember, daughter's, birthday, June, first]
# 15                         [timer, five, seconds]
# 16                              [alarm, for, a_m]
# 17                                         [stop]
# 18                    [add, oranges, and, grapes]
# 19                                         [call]
# 20                                              0
# 21      [Alexa, what, is, in, my, shopping, list]
# 22                                     [hang, up]
# 23                                         [call]
# 24                                     [hang, up]
# 25                                  [find, phone]
# 26                                         [quit]
# 27         [Alexa, turn, the, bedroom, light, on]
# 28                                          [red]
# 29                      [change, brightness, ten]
# 30                                          [off]
# 31                                         [open]
# 32                                         [hide]
# 33                      [white, collar, fire, tv]
# 34                                        [pause]
#
#                                             Utterance         Timestamp  \
# 0       [Alexa, what, is, the, weather, outside, ?, ]         [0, 2800]
# 1               [Alexa, what, is, today's, date, ?, ]      [2800, 5390]
# 2                    [Alexa, what, time, is, it, ?, ]      [5390, 7620]
# 3                [Alexa, when, is, Thanksgiving, ?, ]     [7620, 11270]
# 4   [Alexa, how, do, you, bake, chocolate, chip, c...    [11270, 15840]
# 5            [Alexa, what, is, two, times, four, ?, ]    [15840, 19580]
# 6    [Alexa, how, many, tablespoons, in, a, cup, ?, ]    [19580, 22920]
# 7          [Alexa, how, do, you, spell, symptom, ?, ]    [22920, 26170]
# 8                [Alexa, play, classical, music, ., ]    [26170, 29930]
# 9                    [Alexa, use, volume, eight, ., ]    [29930, 33790]
# 10                  [Alexa, [*no, text, stored], ., ]    [33790, 43110]
# 11  [Alexa, remind, me, to, start, the, laundry, t...    [43110, 48650]
# 12  [Alexa, remind, me, to, feed, the, dog, at, se...    [48650, 54150]
# 13              [Alexa, tell, me, my, reminders, ., ]    [54150, 57640]
# 14  [Alexa, remember, my, daughter's, birthday, is...    [57640, 63470]
# 15     [Alexa, set, a, timer, in, five, seconds, ., ]    [63470, 68170]
# 16      [Alexa, set, my, alarm, for, seven, a_m, ., ]    [68170, 72420]
# 17                                 [Alexa, stop, ., ]    [72420, 74020]
# 18  [Alexa, add, oranges, and, grapes, to, my, sho...    [74020, 79010]
# 19                                 [Alexa, call, ., ]    [79010, 82630]
# 20     [Alexa, what, is, in, my, shopping, cart, ?, ]    [82630, 85970]
# 21     [Alexa, what, is, in, my, shopping, list, ?, ]    [85970, 88980]
# 22                             [Alexa, hang, up, ., ]    [88980, 91790]
# 23  [Alexa, call, six, zero, three, six, six, zero...   [91790, 102120]
# 24                             [Alexa, hang, up, ., ]  [102120, 105110]
# 25                      [Alexa, find, my, phone, ., ]  [105110, 108040]
# 26                                 [Alexa, quit, ., ]  [108040, 110910]
# 27        [Alexa, turn, the, bedroom, light, on, ., ]  [110910, 115060]
# 28       [Alexa, turn, the, bedroom, light, red, ., ]  [115060, 119060]
# 29          [Alexa, change, brightness, to, ten, ., ]  [119060, 123540]
# 30       [Alexa, turn, off, the, bedroom, light, ., ]  [123540, 127060]
# 31           [Alexa, open, the, kitchen, camera, ., ]  [127060, 130790]
# 32           [Alexa, hide, the, kitchen, camera, ., ]  [130790, 134550]
# 33    [Alexa, play, white, collar, on, fire, tv, ., ]  [134550, 140780]
# 34                                [Alexa, pause, ., ]  [140780, 143220]
#
#     % Command-Utterance Match  \
# 0                    1.000000
# 1                    1.000000
# 2                    1.000000
# 3                    1.000000
# 4                    1.000000
# 5                    1.000000
# 6                    1.000000
# 7                    1.000000
# 8                    1.000000
# 9                    0.913043
# 10                   0.615385
# 11                   1.000000
# 12                   1.000000
# 13                   1.000000
# 14                   1.000000
# 15                   1.000000
# 16                   0.886076
# 17                   1.000000
# 18                   1.000000
# 19                   0.740741
# 20                   0.916667
# 21                   1.000000
# 22                   1.000000
# 23                   1.000000
# 24                   1.000000
# 25                   1.000000
# 26                   1.000000
# 27                   1.000000
# 28                   1.000000
# 29                   1.000000
# 30                   1.000000
# 31                   1.000000
# 32                   1.000000
# 33                   1.000000
# 34                   1.000000
#
#                                      Closest Neighbor
# 0                Alexa what is the weather outside ?
# 1                       Alexa what is today's date ?
# 2                            Alexa what time is it ?
# 3                       Alexa when is Thanksgiving ?
# 4     Alexa how do you bake chocolate chip cookies ?
# 5                     Alexa what is two times four ?
# 6              Alexa how many tablespoons in a cup ?
# 7                   Alexa how do you spell symptom ?
# 8                       Alexa play classical music .
# 9                               Alexa volume eight .
# 10                                      Alexa stop .
# 11  Alexa remind me to start the laundry tomorrow ...
# 12  Alexa remind me to feed the dog at seven p_m e...
# 13                      Alexa tell me my reminders .
# 14  Alexa remember my daughter's birthday is June ...
# 15               Alexa set a timer in five seconds .
# 16       Alexa set my alarm for seven a_m tomorrow .
# 17                                      Alexa stop .
# 18  Alexa add oranges and grapes to my shopping li...
# 19                                     Alexa pause .
# 20               Alexa what is in my shopping list ?
# 21               Alexa what is in my shopping list ?
# 22                                   Alexa hang up .
# 23  Alexa call six zero three six six zero two two...
# 24                                   Alexa hang up .
# 25                             Alexa find my phone .
# 26                                      Alexa quit .
# 27                 Alexa turn the bedroom light on .
# 28                Alexa turn the bedroom light red .
# 29                  Alexa change brightness to ten .
# 30                Alexa turn off the bedroom light .
# 31                   Alexa open the kitchen camera .
# 32                   Alexa hide the kitchen camera .
# 33              Alexa play white collar on fire tv .
# 34                                     Alexa pause .
# C:\Users\EliKurtz\VSCode_files\NLP\Kurtz-NLP\Audio gEMAPS\035.cha
# [0, 2950]
# calling from 1
# [2950, 6980]
# calling from 1
# [6980, 10200]
# calling from 1
# [10200, 14270]
# calling from 1
# [14270, 19210]
# calling from 1
# [19210, 23430]
# calling from 1
# [23430, 28280]
# calling from 1
# [28280, 32290]
# calling from 1
# [32290, 36420]
# calling from 1
# [36420, 40010]
# calling from 1
# [40010, 42570]
# calling from 1
# [42570, 46160]
# calling from 1
# [46160, 48150]
# calling from 1
# [48150, 52790]
# calling from 1
# [59850, 64580]
# calling from 1
# [64580, 70170]
# calling from 1
# [76780, 81630]
# calling from 1
# [82930, 86900]
# calling from 1
# [89610, 92800]
# calling from 1
# [92800, 99420]
# calling from 1
# [99420, 102850]
# calling from 1
# [105870, 113000]
# calling from 1
# [117260, 122110]
# calling from 1
# [122110, 124130]
# calling from 1
# [128890, 134760]
# calling from 1
# [137740, 142650]
# calling from 1
# [153040, 156390]
# calling from 1
# [156390, 159920]
# calling from 1
# [159920, 163810]
# calling from 1
# [163810, 166040]
# calling from 1
# [166040, 171430]
# calling from 1
# [171430, 176010]
# calling from 1
# [178010, 182770]
# calling from 1
# [182770, 187170]
# calling from 1
# [189170, 193290]
# calling from 1
# [193290, 198430]
# calling from 1
# [198430, 201480]
# calling from 1
# [201480, 205250]
# calling from 1
# 12
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav', '035.cha_UNMATCHED6.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav', '035.cha_UNMATCHED6.wav', '035.cha_UNMATCHED7.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav', '035.cha_UNMATCHED6.wav', '035.cha_UNMATCHED7.wav', '035.cha_UNMATCHED8.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav', '035.cha_UNMATCHED6.wav', '035.cha_UNMATCHED7.wav', '035.cha_UNMATCHED8.wav', '035.cha_UNMATCHED9.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED10.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav', '035.cha_UNMATCHED6.wav', '035.cha_UNMATCHED7.wav', '035.cha_UNMATCHED8.wav', '035.cha_UNMATCHED9.wav']
# [[52790, 55410], [55410, 56620], [56620, 59850], [81630, 82930], [86900, 89610], [102850, 105870], [113000, 114210], [114210, 116050], [124130, 127440], [127440, 128890], [134760, 137740], [142650, 153040]]
# ['035.cha_UNMATCHED0.wav', '035.cha_UNMATCHED1.wav', '035.cha_UNMATCHED10.wav', '035.cha_UNMATCHED11.wav', '035.cha_UNMATCHED2.wav', '035.cha_UNMATCHED3.wav', '035.cha_UNMATCHED4.wav', '035.cha_UNMATCHED5.wav', '035.cha_UNMATCHED6.wav', '035.cha_UNMATCHED7.wav', '035.cha_UNMATCHED8.wav', '035.cha_UNMATCHED9.wav']
# calling from 3
# [[70170, 75570], [75570, 76780], [116050, 117260], [176010, 178010], [187170, 189170]]
# [[70170, 75570], [75570, 76780], [116050, 117260], [176010, 178010], [187170, 189170]]
# ['035.cha_UNRECOGNIZED0.wav']
# [[70170, 75570], [75570, 76780], [116050, 117260], [176010, 178010], [187170, 189170]]
# ['035.cha_UNRECOGNIZED0.wav', '035.cha_UNRECOGNIZED1.wav']
# [[70170, 75570], [75570, 76780], [116050, 117260], [176010, 178010], [187170, 189170]]
# ['035.cha_UNRECOGNIZED0.wav', '035.cha_UNRECOGNIZED1.wav', '035.cha_UNRECOGNIZED2.wav']
# [[70170, 75570], [75570, 76780], [116050, 117260], [176010, 178010], [187170, 189170]]
# ['035.cha_UNRECOGNIZED0.wav', '035.cha_UNRECOGNIZED1.wav', '035.cha_UNRECOGNIZED2.wav', '035.cha_UNRECOGNIZED3.wav']
# [[70170, 75570], [75570, 76780], [116050, 117260], [176010, 178010], [187170, 189170]]
# ['035.cha_UNRECOGNIZED0.wav', '035.cha_UNRECOGNIZED1.wav', '035.cha_UNRECOGNIZED2.wav', '035.cha_UNRECOGNIZED3.wav', '035.cha_UNRECOGNIZED4.wav']
# calling from 4
#    Participant          Matched Command  \
# 0      035.cha            [[command_1]]
# 1      035.cha            [[command_2]]
# 2      035.cha            [[command_3]]
# 3      035.cha            [[command_4]]
# 4      035.cha            [[command_5]]
# 5      035.cha            [[command_6]]
# 6      035.cha            [[command_7]]
# 7      035.cha            [[command_8]]
# 8      035.cha            [[command_9]]
# 9      035.cha           [[command_10]]
# 10     035.cha           [[command_11]]
# 11     035.cha           [[command_12]]
# 12     035.cha           [[command_13]]
# 13     035.cha           [[command_14]]
# 14     035.cha   [UNMATCHED COMMAND #1]
# 15     035.cha   [UNMATCHED COMMAND #2]
# 16     035.cha   [UNMATCHED COMMAND #3]
# 17     035.cha           [[command_14]]
# 18     035.cha           [[command_15]]
# 19     035.cha     UNRECOGNIZED COMMAND
# 20     035.cha     UNRECOGNIZED COMMAND
# 21     035.cha           [[command_14]]
# 22     035.cha   [UNMATCHED COMMAND #4]
# 23     035.cha           [[command_14]]
# 24     035.cha   [UNMATCHED COMMAND #5]
# 25     035.cha           [[command_16]]
# 26     035.cha           [[command_15]]
# 27     035.cha           [[command_16]]
# 28     035.cha   [UNMATCHED COMMAND #6]
# 29     035.cha           [[command_17]]
# 30     035.cha   [UNMATCHED COMMAND #7]
# 31     035.cha   [UNMATCHED COMMAND #8]
# 32     035.cha     UNRECOGNIZED COMMAND
# 33     035.cha           [[command_18]]
# 34     035.cha           [[command_13]]
# 35     035.cha   [UNMATCHED COMMAND #9]
# 36     035.cha  [UNMATCHED COMMAND #10]
# 37     035.cha           [[command_20]]
# 38     035.cha  [UNMATCHED COMMAND #11]
# 39     035.cha           [[command_22]]
# 40     035.cha  [UNMATCHED COMMAND #12]
# 41     035.cha           [[command_23]]
# 42     035.cha           [[command_23]]
# 43     035.cha           [[command_24]]
# 44     035.cha           [[command_25]]
# 45     035.cha           [[command_26]]
# 46     035.cha           [[command_27]]
# 47     035.cha     UNRECOGNIZED COMMAND
# 48     035.cha           [[command_29]]
# 49     035.cha           [[command_30]]
# 50     035.cha     UNRECOGNIZED COMMAND
# 51     035.cha           [[command_31]]
# 52     035.cha           [[command_32]]
# 53     035.cha           [[command_33]]
# 54     035.cha           [[command_33]]
#
#                                  Unique Key-Words  \
# 0                              [weather, outside]
# 1                                 [today's, date]
# 2                                      [time, it]
# 3                            [when, Thanksgiving]
# 4                [bake, chocolate, chip, cookies]
# 5                                   [times, four]
# 6                        [many, tablespoons, cup]
# 7                                [spell, symptom]
# 8                              [classical, music]
# 9                                         [eight]
# 10                                         [jazz]
# 11                           [Alexa, volume, six]
# 12                                         [stop]
# 13                               [start, laundry]
# 14                                              0
# 15                                              0
# 16                                              0
# 17                               [start, laundry]
# 18                          [feed, dog, everyday]
# 19                                              0
# 20                                              0
# 21                               [start, laundry]
# 22                                              0
# 23                               [start, laundry]
# 24                                              0
# 25                              [tell, reminders]
# 26                          [feed, dog, everyday]
# 27                              [tell, reminders]
# 28                                              0
# 29  [remember, daughter's, birthday, June, first]
# 30                                              0
# 31                                              0
# 32                                              0
# 33                         [timer, five, seconds]
# 34                                         [stop]
# 35                                              0
# 36                                              0
# 37                    [add, oranges, and, grapes]
# 38                                              0
# 39                                         [call]
# 40                                              0
# 41                                     [hang, up]
# 42                                     [hang, up]
# 43                                  [find, phone]
# 44                                         [quit]
# 45         [Alexa, turn, the, bedroom, light, on]
# 46                                          [red]
# 47                                              0
# 48                                          [off]
# 49                                         [open]
# 50                                              0
# 51                                         [hide]
# 52                      [white, collar, fire, tv]
# 53                                        [pause]
# 54                                        [pause]
#
#                                             Utterance         Timestamp  \
# 0       [Alexa, what, is, the, weather, outside, ?, ]         [0, 2950]
# 1               [Alexa, what, is, today's, date, ?, ]      [2950, 6980]
# 2                    [Alexa, what, time, is, it, ?, ]     [6980, 10200]
# 3                [Alexa, when, is, Thanksgiving, ?, ]    [10200, 14270]
# 4   [Alexa, how, do, you, bake, chocolate, chip, c...    [14270, 19210]
# 5            [Alexa, what, is, two, times, four, ?, ]    [19210, 23430]
# 6    [Alexa, how, many, tablespoons, in, a, cup, ?, ]    [23430, 28280]
# 7          [Alexa, how, do, you, spell, symptom, ?, ]    [28280, 32290]
# 8                [Alexa, play, classical, music, ., ]    [32290, 36420]
# 9                         [Alexa, volume, eight, ., ]    [36420, 40010]
# 10                           [Alexa, play, jazz, ., ]    [40010, 42570]
# 11                          [Alexa, volume, six, ., ]    [42570, 46160]
# 12                                 [Alexa, stop, ., ]    [46160, 48150]
# 13  [Alexa, remind, me, to, start, the, laundry, t...    [48150, 52790]
# 14              [remind, me, to, feed, the, dog, ., ]    [52790, 55410]
# 15                                          [a., ., ]    [55410, 56620]
# 16  [Alexa, [*audio, could, not, be, understood], ...    [56620, 59850]
# 17  [Alexa, remind, me, to, start, the, laundry, ., ]    [59850, 64580]
# 18  [remind, me, feed, the, dog, at, seven, a_m, e...    [64580, 70170]
# 19                                         [[*], ., ]    [70170, 75570]
# 20        [[*audio, could, not, be, understood], ., ]    [75570, 76780]
# 21  [Alexa, remind, me, to, start, the, laundry, t...    [76780, 81630]
# 22                                    [in, here, ., ]    [81630, 82930]
# 23  [Alexa, remind, me, to, start, the, laundry, t...    [82930, 86900]
# 24                                    [two, p_m, ., ]    [86900, 89610]
# 25              [Alexa, tell, me, my, reminders, ., ]    [89610, 92800]
# 26  [Alexa, remind, me, to, feed, the, dog, at, se...    [92800, 99420]
# 27              [Alexa, tell, me, my, reminders, ., ]   [99420, 102850]
# 28                          [Alexa, never, mind, ., ]  [102850, 105870]
# 29  [Alexa, remember, my, daughter's, birthday, is...  [105870, 113000]
# 30                                         [yes, ., ]  [113000, 114210]
# 31                                 [yes, please, ., ]  [114210, 116050]
# 32        [[*audio, could, not, be, understood], ., ]  [116050, 117260]
# 33     [Alexa, set, a, timer, in, five, seconds, ., ]  [117260, 122110]
# 34                                 [Alexa, stop, ., ]  [122110, 124130]
# 35           [Alexa, set, my, alarm, for, seven, ., ]  [124130, 127440]
# 36                                     [morning, ., ]  [127440, 128890]
# 37  [Alexa, add, oranges, and, grapes, to, my, sho...  [128890, 134760]
# 38     [Alexa, what, is, on, my, shopping, list, ?, ]  [134760, 137740]
# 39               [Alexa, call, six, zero, three, ., ]  [137740, 142650]
# 40  [six, zero, three, six, six, zero, two, two, z...  [142650, 153040]
# 41                             [Alexa, hang, up, ., ]  [153040, 156390]
# 42                             [Alexa, hang, up, ., ]  [156390, 159920]
# 43                      [Alexa, find, my, phone, ., ]  [159920, 163810]
# 44                                 [Alexa, quit, ., ]  [163810, 166040]
# 45        [Alexa, turn, the, bedroom, light, on, ., ]  [166040, 171430]
# 46       [Alexa, turn, the, bedroom, light, red, ., ]  [171430, 176010]
# 47    [[*audio, was, not, intended, for, Alexa], ., ]  [176010, 178010]
# 48       [Alexa, turn, off, the, bedroom, light, ., ]  [178010, 182770]
# 49           [Alexa, open, the, kitchen, camera, ., ]  [182770, 187170]
# 50    [[*audio, was, not, intended, for, Alexa], ., ]  [187170, 189170]
# 51           [Alexa, hide, the, kitchen, camera, ., ]  [189170, 193290]
# 52    [Alexa, play, white, collar, on, fire, tv, ., ]  [193290, 198430]
# 53                                [Alexa, pause, ., ]  [198430, 201480]
# 54                                [Alexa, pause, ., ]  [201480, 205250]
#
#    % Command-Utterance Match  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# 5                        1.0
# 6                        1.0
# 7                        1.0
# 8                        1.0
# 9                        1.0
# 10                       1.0
# 11                       1.0
# 12                       1.0
# 13                  0.897196
# 14                  0.666667
# 15                  0.444444
# 16                  0.538462
# 17                  0.795918
# 18                  0.893204
# 19                       N/A
# 20                       N/A
# 21                  0.897196
# 22                       0.5
# 23                  0.897196
# 24                  0.434783
# 25                       1.0
# 26                       1.0
# 27                       1.0
# 28                  0.631579
# 29                       1.0
# 30                  0.526316
# 31                  0.592593
# 32                       N/A
# 33                       1.0
# 34                       1.0
# 35                  0.826667
# 36                  0.387097
# 37                       1.0
# 38                  0.972222
# 39                  0.636364
# 40                  0.899083
# 41                       1.0
# 42                       1.0
# 43                       1.0
# 44                       1.0
# 45                       1.0
# 46                       1.0
# 47                       N/A
# 48                       1.0
# 49                       1.0
# 50                       N/A
# 51                       1.0
# 52                       1.0
# 53                       1.0
# 54                       1.0
#
#                                      Closest Neighbor
# 0                Alexa what is the weather outside ?
# 1                       Alexa what is today's date ?
# 2                            Alexa what time is it ?
# 3                       Alexa when is Thanksgiving ?
# 4     Alexa how do you bake chocolate chip cookies ?
# 5                     Alexa what is two times four ?
# 6              Alexa how many tablespoons in a cup ?
# 7                   Alexa how do you spell symptom ?
# 8                       Alexa play classical music .
# 9                               Alexa volume eight .
# 10                                 Alexa play jazz .
# 11                                Alexa volume six .
# 12                                      Alexa stop .
# 13  Alexa remind me to start the laundry tomorrow ...
# 14  Alexa remind me to feed the dog at seven p_m e...
# 15                                      Alexa stop .
# 16              Alexa play white collar on fire tv .
# 17  Alexa remind me to start the laundry tomorrow ...
# 18  Alexa remind me to feed the dog at seven p_m e...
# 19                                                N/A
# 20                                                N/A
# 21  Alexa remind me to start the laundry tomorrow ...
# 22                             Alexa find my phone .
# 23  Alexa remind me to start the laundry tomorrow ...
# 24                                      Alexa stop .
# 25                      Alexa tell me my reminders .
# 26  Alexa remind me to feed the dog at seven p_m e...
# 27                      Alexa tell me my reminders .
# 28                                Alexa volume six .
# 29  Alexa remember my daughter's birthday is June ...
# 30                                      Alexa stop .
# 31                                     Alexa pause .
# 32                                                N/A
# 33               Alexa set a timer in five seconds .
# 34                                      Alexa stop .
# 35       Alexa set my alarm for seven a_m tomorrow .
# 36                              Alexa volume eight .
# 37  Alexa add oranges and grapes to my shopping li...
# 38               Alexa what is in my shopping list ?
# 39  Alexa call six zero three six six zero two two...
# 40  Alexa call six zero three six six zero two two...
# 41                                   Alexa hang up .
# 42                                   Alexa hang up .
# 43                             Alexa find my phone .
# 44                                      Alexa quit .
# 45                 Alexa turn the bedroom light on .
# 46                Alexa turn the bedroom light red .
# 47                                                N/A
# 48                Alexa turn off the bedroom light .
# 49                   Alexa open the kitchen camera .
# 50                                                N/A
# 51                   Alexa hide the kitchen camera .
# 52              Alexa play white collar on fire tv .
# 53                                     Alexa pause .
# 54                                     Alexa pause .
# C:\Users\EliKurtz\VSCode_files\NLP\Kurtz-NLP\Audio gEMAPS\057.cha
# [0, 2620]
# calling from 1
# [2620, 5660]
# calling from 1
# [5660, 7860]
# calling from 1
# [7860, 11420]
# calling from 1
# [11420, 14730]
# calling from 1
# [14730, 18310]
# calling from 1
# [18310, 21830]
# calling from 1
# [27740, 30570]
# calling from 1
# [30570, 32830]
# calling from 1
# [32830, 35030]
# calling from 1
# [35030, 37320]
# calling from 1
# [37320, 39640]
# calling from 1
# [39640, 41630]
# calling from 1
# [41630, 46980]
# calling from 1
# [46980, 51580]
# calling from 1
# [54950, 60750]
# calling from 1
# [63170, 66240]
# calling from 1
# [66240, 68170]
# calling from 1
# [68170, 72140]
# calling from 1
# [72140, 75780]
# calling from 1
# [75780, 79000]
# calling from 1
# [79000, 85790]
# calling from 1
# [85790, 87570]
# calling from 1
# [87570, 89710]
# calling from 1
# [89710, 91700]
# calling from 1
# [91700, 94650]
# calling from 1
# [97330, 100190]
# calling from 1
# [100190, 103410]
# calling from 1
# [103410, 107980]
# calling from 1
# [107980, 110900]
# calling from 1
# [112900, 116810]
# calling from 1
# [116810, 118830]
# calling from 1
# 7
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav']
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav', '057.cha_UNMATCHED1.wav']
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav', '057.cha_UNMATCHED1.wav', '057.cha_UNMATCHED2.wav']
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav', '057.cha_UNMATCHED1.wav', '057.cha_UNMATCHED2.wav', '057.cha_UNMATCHED3.wav']
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav', '057.cha_UNMATCHED1.wav', '057.cha_UNMATCHED2.wav', '057.cha_UNMATCHED3.wav', '057.cha_UNMATCHED4.wav']
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav', '057.cha_UNMATCHED1.wav', '057.cha_UNMATCHED2.wav', '057.cha_UNMATCHED3.wav', '057.cha_UNMATCHED4.wav', '057.cha_UNMATCHED5.wav']
# [[21830, 25080], [26380, 27740], [51580, 54950], [60750, 61960], [61960, 63170], [94650, 97330], [118830, 121420]]
# ['057.cha_UNMATCHED0.wav', '057.cha_UNMATCHED1.wav', '057.cha_UNMATCHED2.wav', '057.cha_UNMATCHED3.wav', '057.cha_UNMATCHED4.wav', '057.cha_UNMATCHED5.wav', '057.cha_UNMATCHED6.wav']
# calling from 3
# [[25080, 26380], [110900, 112900]]
# [[25080, 26380], [110900, 112900]]
# ['057.cha_UNRECOGNIZED0.wav']
# [[25080, 26380], [110900, 112900]]
# ['057.cha_UNRECOGNIZED0.wav', '057.cha_UNRECOGNIZED1.wav']
# calling from 4
#    Participant         Matched Command  \
# 0      057.cha           [[command_1]]
# 1      057.cha           [[command_2]]
# ...
# 36              Alexa play white collar on fire tv .
# 37                                     Alexa pause .
# C:\Users\EliKurtz\VSCode_files\NLP\Kurtz-NLP\Audio gEMAPS\072.cha
# [0, 2740]
# calling from 1
# [2740, 5540]
# calling from 1
# [5540, 7770]
# calling from 1
# [7770, 10330]
# calling from 1
# [14270, 18250]
# calling from 1
# [18250, 22290]
# calling from 1
# [22290, 26290]
# calling from 1
# [26290, 29690]
# calling from 1
# [29690, 32430]
# calling from 1
# [32430, 35300]
# calling from 1
# [35300, 38650]
# calling from 1
# [38650, 42450]
# calling from 1
# [45350, 51430]
# calling from 1
# [51430, 56810]
# calling from 1
# [59230, 63680]
# calling from 1
# [63680, 65730]
# calling from 1
# [65730, 69970]
# calling from 1
# [71970, 75260]
# calling from 1
# [75260, 78660]
# calling from 1
# [83020, 88490]
# calling from 1
# [88490, 91740]
# calling from 1
# [96940, 101570]
# calling from 1
# [101570, 109380]
# calling from 1
# [101570, 109380]
# calling from 1
# [111100, 121880]
# calling from 1
# [123090, 126340]
# calling from 1
# [131990, 137200]
# calling from 1
# 11
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav', '072.cha_UNMATCHED5.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav', '072.cha_UNMATCHED5.wav', '072.cha_UNMATCHED6.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav', '072.cha_UNMATCHED5.wav', '072.cha_UNMATCHED6.wav', '072.cha_UNMATCHED7.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav', '072.cha_UNMATCHED5.wav', '072.cha_UNMATCHED6.wav', '072.cha_UNMATCHED7.wav', '072.cha_UNMATCHED8.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav', '072.cha_UNMATCHED5.wav', '072.cha_UNMATCHED6.wav', '072.cha_UNMATCHED7.wav', '072.cha_UNMATCHED8.wav', '072.cha_UNMATCHED9.wav']
# [[10330, 14270], [42450, 45350], [56810, 58020], [58020, 59230], [78660, 83020], [91740, 94460], [95760, 96940], [109380, 111100], [121880, 123090], [126340, 129180], [129180, 131990]]
# ['072.cha_UNMATCHED0.wav', '072.cha_UNMATCHED1.wav', '072.cha_UNMATCHED10.wav', '072.cha_UNMATCHED2.wav', '072.cha_UNMATCHED3.wav', '072.cha_UNMATCHED4.wav', '072.cha_UNMATCHED5.wav', '072.cha_UNMATCHED6.wav', '072.cha_UNMATCHED7.wav', '072.cha_UNMATCHED8.wav', '072.cha_UNMATCHED9.wav']
# calling from 3
# [[69970, 71970], [94460, 95760]]
# [[69970, 71970], [94460, 95760]]
# ['072.cha_UNRECOGNIZED0.wav']
# [[69970, 71970], [94460, 95760]]
# ['072.cha_UNRECOGNIZED0.wav', '072.cha_UNRECOGNIZED1.wav']
# calling from 4
#    Participant          Matched Command  \
# 0      072.cha            [[command_1]]
# 1      072.cha            [[command_2]]
# 2      072.cha            [[command_3]]
# 3      072.cha            [[command_4]]
# 4      072.cha   [UNMATCHED COMMAND #1]
# 5      072.cha            [[command_6]]
# 6      072.cha            [[command_7]]
# 7      072.cha            [[command_8]]
# 8      072.cha            [[command_9]]
# 9      072.cha           [[command_10]]
# 10     072.cha           [[command_29]]
# 11     072.cha           [[command_11]]
# 12     072.cha           [[command_12]]
# 13     072.cha   [UNMATCHED COMMAND #2]
# 14     072.cha           [[command_14]]
# 15     072.cha           [[command_17]]
# 16     072.cha   [UNMATCHED COMMAND #3]
# 17     072.cha   [UNMATCHED COMMAND #4]
# 18     072.cha           [[command_18]]
# 19     072.cha           [[command_13]]
# 20     072.cha           [[command_19]]
# 21     072.cha     UNRECOGNIZED COMMAND
# 22     072.cha           [[command_26]]
# 23     072.cha           [[command_27]]
# 24     072.cha   [UNMATCHED COMMAND #5]
# 25     072.cha           [[command_15]]
# 26     072.cha           [[command_16]]
# 27     072.cha   [UNMATCHED COMMAND #6]
# 28     072.cha     UNRECOGNIZED COMMAND
# 29     072.cha   [UNMATCHED COMMAND #7]
# 30     072.cha           [[command_20]]
# 31     072.cha           [[command_10]]
# 32     072.cha           [[command_22]]
# 33     072.cha   [UNMATCHED COMMAND #8]
# 34     072.cha           [[command_22]]
# 35     072.cha   [UNMATCHED COMMAND #9]
# 36     072.cha           [[command_30]]
# 37     072.cha  [UNMATCHED COMMAND #10]
# 38     072.cha  [UNMATCHED COMMAND #11]
# 39     072.cha           [[command_32]]
#
#                                  Unique Key-Words  \
# 0                              [weather, outside]
# 1                                 [today's, date]
# 2                                      [time, it]
# 3                            [when, Thanksgiving]
# 4                                               0
# 5                                   [times, four]
# 6                        [many, tablespoons, cup]
# 7                                [spell, symptom]
# 8                              [classical, music]
# 9                                         [eight]
# 10                                          [off]
# 11                                         [jazz]
# 12                           [Alexa, volume, six]
# 13                                              0
# 14                               [start, laundry]
# 15  [remember, daughter's, birthday, June, first]
# 16                                              0
# 17                                              0
# 18                         [timer, five, seconds]
# 19                                         [stop]
# 20                              [alarm, for, a_m]
# 21                                              0
# 22         [Alexa, turn, the, bedroom, light, on]
# 23                                          [red]
# 24                                              0
# 25                          [feed, dog, everyday]
# 26                              [tell, reminders]
# 27                                              0
# 28                                              0
# 29                                              0
# 30                    [add, oranges, and, grapes]
# 31                                        [eight]
# 32                                         [call]
# 33                                              0
# 34                                         [call]
# 35                                              0
# 36                                         [open]
# 37                                              0
# 38                                              0
# 39                      [white, collar, fire, tv]
#
#                                             Utterance         Timestamp  \
# 0       [Alexa, what, is, the, weather, outside, ?, ]         [0, 2740]
# 1               [Alexa, what, is, today's, date, ?, ]      [2740, 5540]
# 2                    [Alexa, what, time, is, it, ?, ]      [5540, 7770]
# 3                [Alexa, when, is, Thanksgiving, ?, ]     [7770, 10330]
# 4   [Alexa, how, do, you, make, chocolate, chip, c...    [10330, 14270]
# 5            [Alexa, what, is, two, times, four, ?, ]    [14270, 18250]
# 6    [Alexa, how, many, tablespoons, in, a, cup, ?, ]    [18250, 22290]
# 7          [Alexa, how, do, you, spell, symptom, ?, ]    [22290, 26290]
# 8                [Alexa, play, classical, music, ., ]    [26290, 29690]
# 9                         [Alexa, volume, eight, ., ]    [29690, 32430]
# 10                                  [Alexa, off, ., ]    [32430, 35300]
# 11                           [Alexa, play, jazz, ., ]    [35300, 38650]
# 12                          [Alexa, volume, six, ., ]    [38650, 42450]
# 13  [Alexa, [*audio, could, not, be, understood], ...    [42450, 45350]
# 14  [Alexa, remind, me, to, start, the, laundry, t...    [45350, 51430]
# 15  [Alexa, remember, my, daughter's, birthday, is...    [51430, 56810]
# 16                                         [yes, ., ]    [56810, 58020]
# 17                              [no, thank, you, ., ]    [58020, 59230]
# 18     [Alexa, set, a, timer, in, five, seconds, ., ]    [59230, 63680]
# 19                                 [Alexa, stop, ., ]    [63680, 65730]
# 20  [Alexa, set, my, alarm, for, seven, a_m, tomor...    [65730, 69970]
# 21    [[*audio, was, not, intended, for, Alexa], ., ]    [69970, 71970]
# 22        [Alexa, turn, the, bedroom, light, on, ., ]    [71970, 75260]
# 23       [Alexa, turn, the, bedroom, light, red, ., ]    [75260, 78660]
# 24                   [Alexa, change, brightness, ., ]    [78660, 83020]
# 25  [Alexa, remind, me, to, feed, the, dog, at, se...    [83020, 88490]
# 26              [Alexa, tell, me, my, reminders, ., ]    [88490, 91740]
# 27  [Alexa, [*audio, could, not, be, understood], ...    [91740, 94460]
# 28        [[*audio, could, not, be, understood], ., ]    [94460, 95760]
# 29                              [shopping, list, ., ]    [95760, 96940]
# 30  [Alexa, add, oranges, and, grapes, to, my, sho...   [96940, 101570]
# 31  [Alexa, call, eight, oh, three, six, six, zero...  [101570, 109380]
# 32  [Alexa, call, eight, oh, three, six, six, zero...  [101570, 109380]
# 33                                          [no, ., ]  [109380, 111100]
# 34  [Alexa, call, zero, three, zero, zero, three, ...  [111100, 121880]
# 35                                          [no, ., ]  [121880, 123090]
# 36           [Alexa, open, the, kitchen, camera, ., ]  [123090, 126340]
# 37                                    [Alexa, I, ., ]  [126340, 129180]
# 38                                    [Alexa, I, ., ]  [129180, 131990]
# 39    [Alexa, play, white, collar, on, fire, tv, ., ]  [131990, 137200]
#
#    % Command-Utterance Match  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                   0.978723
# 5                        1.0
# 6                        1.0
# 7                        1.0
# 8                        1.0
# 9                        1.0
# 10                       0.8
# 11                       1.0
# 12                       1.0
# 13                  0.538462
# 14                       1.0
# 15                       1.0
# 16                  0.526316
# 17                  0.580645
# 18                       1.0
# 19                       1.0
# 20                       1.0
# 21                       N/A
# 22                       1.0
# 23                       1.0
# 24                  0.881356
# 25                       1.0
# 26                       1.0
# 27                  0.538462
# 28                       N/A
# 29                  0.576923
# 30                       1.0
# 31                  0.842975
# 32                  0.842975
# 33                  0.444444
# 34                       0.8
# 35                  0.444444
# 36                       1.0
# 37                  0.782609
# 38                  0.782609
# 39                       1.0
#
#                                      Closest Neighbor
# 0                Alexa what is the weather outside ?
# 1                       Alexa what is today's date ?
# 2                            Alexa what time is it ?
# 3                       Alexa when is Thanksgiving ?
# 4     Alexa how do you bake chocolate chip cookies ?
# 5                     Alexa what is two times four ?
# 6              Alexa how many tablespoons in a cup ?
# 7                   Alexa how do you spell symptom ?
# 8                       Alexa play classical music .
# 9                               Alexa volume eight .
# 10                                      Alexa stop .
# 11                                 Alexa play jazz .
# 12                                Alexa volume six .
# 13              Alexa play white collar on fire tv .
# 14  Alexa remind me to start the laundry tomorrow ...
# 15  Alexa remember my daughter's birthday is June ...
# 16                                      Alexa stop .
# 17                                   Alexa hang up .
# 18               Alexa set a timer in five seconds .
# 19                                      Alexa stop .
# 20       Alexa set my alarm for seven a_m tomorrow .
# 21                                                N/A
# 22                 Alexa turn the bedroom light on .
# 23                Alexa turn the bedroom light red .
# 24                  Alexa change brightness to ten .
# 25  Alexa remind me to feed the dog at seven p_m e...
# 26                      Alexa tell me my reminders .
# 27              Alexa play white collar on fire tv .
# 28                                                N/A
# 29               Alexa what is in my shopping list ?
# 30  Alexa add oranges and grapes to my shopping li...
# 31  Alexa call six zero three six six zero two two...
# 32  Alexa call six zero three six six zero two two...
# 33                                      Alexa stop .
# 34  Alexa call six zero three six six zero two two...
# 35                                      Alexa stop .
# 36                   Alexa open the kitchen camera .
# 37                                      Alexa stop .
# 38                                      Alexa stop .
# 39              Alexa play white collar on fire tv .
